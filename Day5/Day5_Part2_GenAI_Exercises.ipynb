# %% [markdown]
# # Day 5 Part 2 — Generative AI Exercises
#
# **Instructions:**
# 1. Read each exercise carefully
# 2. Identify which Generative AI task it belongs to
# 3. Write the code using Mistral Large (replicate the pattern from the class notebook)
# 4. Run your code and verify the output
#
# **Available Tasks:** Text Generation, Summarization, Translation, Question Answering, Code Generation, Sentiment Analysis, Text Classification, Chatbot/Conversation, Data Extraction (NER), Paraphrasing

# %% [markdown]
# ---
# ## Setup

# %%
import sys
# !{sys.executable} -m pip install langchain-mistralai langchain-core

# %%
import os
from langchain_mistralai import ChatMistralAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

os.environ["MISTRAL_API_KEY"] = "your-mistral-api-key-here"

llm = ChatMistralAI(
    model="mistral-large-latest",
    temperature=0.7,
    max_retries=2,
)

print("Model ready:", llm.model)

# %% [markdown]
# ---
# ## Exercise 1
#
# You are given the following customer reviews:
#
# - "The food was absolutely delicious and the service was excellent!"
# - "Waited 45 minutes for cold food. Never coming back."
# - "Average experience. Nothing memorable."
#
# **Your task:** Determine the emotional tone of each review. Use the model to classify each one.
#
# *What GenAI task is this?* ____________________

# %%
# Exercise 1: Write your code here

# %% [markdown]
# ---
# ## Exercise 2
#
# Given this paragraph:
#
# > "Cloud computing is the delivery of computing services—including servers, storage, databases, networking, software, analytics, and intelligence—over the Internet to offer faster innovation, flexible resources, and economies of scale. Companies of every type, size, and industry use cloud computing for a variety of use cases, such as data backup, disaster recovery, email, virtual desktops, software development and testing, big data analytics, and customer-facing web applications."
#
# **Your task:** Reduce this to 2 concise sentences that capture the key points.
#
# *What GenAI task is this?* ____________________

# %%
# Exercise 2: Write your code here

# %% [markdown]
# ---
# ## Exercise 3
#
# Convert the following sentence into **Tamil** and **Japanese**:
#
# "Artificial Intelligence is reshaping how we live and work."
#
# **Your task:** Use the model to produce translations in both languages.
#
# *What GenAI task is this?* ____________________

# %%
# Exercise 3: Write your code here

# %% [markdown]
# ---
# ## Exercise 4
#
# You need a Python function that:
# - Takes a list of numbers as input
# - Returns a new list with only the even numbers
# - Should include comments explaining each step
#
# **Your task:** Ask the model to write this function for you using natural language.
#
# *What GenAI task is this?* ____________________

# %%
# Exercise 4: Write your code here

# %% [markdown]
# ---
# ## Exercise 5
#
# Read this text:
#
# > "Elon Musk, CEO of Tesla and SpaceX, visited Chennai on March 15, 2025 to announce a new Gigafactory project in collaboration with the Tamil Nadu government. The factory is expected to create 10,000 jobs."
#
# **Your task:** Extract all the people, organizations, locations, and dates from this text in a structured format.
#
# *What GenAI task is this?* ____________________

# %%
# Exercise 5: Write your code here

# %% [markdown]
# ---
# ## Exercise 6
#
# You want to have a conversation with an AI tutor about "What is Deep Learning?"
#
# - Turn 1: Ask "What is deep learning?"
# - Turn 2: Follow up with "How is it different from machine learning?"
# - Turn 3: Ask "Give me one real-world application."
#
# **Your task:** Write code that maintains conversation history across all 3 turns so the model remembers context.
#
# *What GenAI task is this?* ____________________

# %%
# Exercise 6: Write your code here
